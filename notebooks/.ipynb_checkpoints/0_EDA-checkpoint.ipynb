# %% [markdown]
# # Explorative Data-Analytics
# Dieses Notbook dient der ersten Berührung mit dem Datensatz. Hierzu werden grundlegende Sichtungen druchgeführt.

# %% [markdown]
# ## Bibliotheken

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Daten laden
# daten laden / erstbehnadlung missing values || im orginal ds als "?", ich konvertiere zu np.nan / Ändern datatype alles auf float bis auf normalized loss

# %%
labelList=['symboling','normalizedLosses','make','fuelType','aspiration','numOfDoors','bodyStyle','driveWheels','engineLocation',
           'wheelBase','length','width','height','curbWeight','engineType','numOfCylinders','engineSize','fuelSystem','bore',
           'stroke','compressionRatio','horsepower','peakRpm','cityMpg','highwayMpg','price']
df = pd.read_csv('../data/data_car-CopyForEDA.csv',delimiter=',',encoding='utf-8', names=labelList)
# Datentypen umwandeln & ? durch np.NAN ersetzen
df = df.replace("?", np.nan)
df[['normalizedLosses']]=df[['normalizedLosses']].astype('category') #
df[['price']]=df[['price']].astype('float64')
df[['horsepower']]=df[['horsepower']].astype('float64')
df[['peakRpm']]=df[['peakRpm']].astype('float64')
df[['bore']]=df[['bore']].astype('float64')
df[['stroke']]=df[['stroke']].astype('float64')
df[['engineSize']]=df[['engineSize']].astype('float64')
df[['cityMpg']]=df[['cityMpg']].astype('float64')
df[['highwayMpg']]=df[['highwayMpg']].astype('float64')
df[['curbWeight']]=df[['curbWeight']].astype('float64')

# %% [markdown]
# ## Informationen aus dem DF
# es gibt die Dtypen int64, object, float64 und category<br>
# Die featurenormalizedLosses, numOfDoors,bore, stroke horsepower,peakRPM haben missings(np.nans) => hier wird auf irgendeine weise imputed werden<br>
# die Information aus der Funktion describe ist für mich , dass es auf den ersten Blick (vgl mean, max, min) die Daten für mich nicht großartig mit ausreißern "gespickt sind" => Hilfestellung für die Skalierung

# %%
df.info()
df.isna().any()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling           205 non-null int64
# normalizedLosses    164 non-null category
# make                205 non-null object
# fuelType            205 non-null object
# aspiration          205 non-null object
# numOfDoors          203 non-null object
# bodyStyle           205 non-null object
# driveWheels         205 non-null object
# engineLocation      205 non-null object
# wheelBase           205 non-null float64
# length              205 non-null float64
# width               205 non-null float64
# height              205 non-null float64
# curbWeight          205 non-null float64
# engineType          205 non-null object
# numOfCylinders      205 non-null object
# engineSize          205 non-null float64
# fuelSystem          205 non-null object
# bore                201 non-null float64
# stroke              201 non-null float64
# compressionRatio    205 non-null float64
# horsepower          203 non-null float64
# peakRpm             203 non-null float64
# cityMpg             205 non-null float64
# highwayMpg          205 non-null float64
# price               201 non-null float64
# dtypes: category(1), float64(14), int64(1), object(10)
# memory usage: 43.3+ KB
#         symboling   wheelBase      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbWeight  engineSize        bore      stroke  compressionRatio  \
# count   205.000000  205.000000  201.000000  201.000000        205.000000
# mean   2555.565854  126.907317    3.329751    3.255423         10.142537
# std     520.680204   41.642693    0.273539    0.316717          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.590000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakRpm     cityMpg  highwayMpg         price
# count  203.000000   203.000000  205.000000  205.000000    201.000000
# mean   104.256158  5125.369458   25.219512   30.751220  13207.129353
# std     39.714369   479.334560    6.542142    6.886443   7947.066342
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7775.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16500.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# # Korrelationen
# Wenden wir auf unser DF nun Funktionnen der Korrelation an, so werden automatisch lediglich die numerischen Feature einbezogen.

# %%
df.corr()[["price"]].sort_values(by="price")
# Out:
#                      price
# highwayMpg       -0.704692
# cityMpg          -0.686571
# peakRpm          -0.101649
# symboling        -0.082391
# compressionRatio  0.071107
# stroke            0.082310
# height            0.135486
# bore              0.543436
# wheelBase         0.584642
# length            0.690628
# width             0.751265
# horsepower        0.810533
# curbWeight        0.834415
# engineSize        0.872335
# price             1.000000

# %% [markdown]
# Uns interessiert wie die Variablen zusammenhängen, dies wird u.a. in der Korrelation ausgedrückt. Die Variable Preis eines Fahrzeugs scheint somit in erster Linie von der engineSize (Hubraum), dem CrubWeight Leergewicht und der Horsepower(PS) abhängig zu sein. Das würde nun bedeuten, dass schwere Fahrzeuge (Bspw SUV) und höher motorisierte Fahzeuge(engine size & HP) grundsäzlich teuere sind. So weit scheint das für mich nachvollziehbar.

# %%
df.corr()[["symboling"]].sort_values(by="symboling")
# Out:
#                   symboling
# height            -0.541038
# wheelBase         -0.531954
# length            -0.357612
# width             -0.232919
# curbWeight        -0.227691
# compressionRatio  -0.178515
# bore              -0.134205
# engineSize        -0.105790
# price             -0.082391
# cityMpg           -0.035823
# stroke            -0.008965
# highwayMpg         0.034606
# horsepower         0.071622
# peakRpm            0.274573
# symboling          1.000000

# %% [markdown]
# betrachten wir nun die Zusammenhänge für die Versicherungseinstufung(symboling) so scheinen die Parameter HP&Peakrpm ("ganz" indirekt somit auch der Verbauch highwaympg) ausschlaggebend zu sein. je gößer der Wert in symboling ist, desto risikoreicher ist die Einstufung, die durch dieses Skala ausgedrückt werden soll. <br>
#
# Nachfolgend habe ich nochmals die nicht gefilterte Korrelation zunächst in Tabellenform und anschließend als heatmap dargestellt.

# %%
df.corr()
# Out:
#                   symboling  wheelBase    length     width    height  \
# symboling          1.000000  -0.531954 -0.357612 -0.232919 -0.541038
# wheelBase         -0.531954   1.000000  0.874587  0.795144  0.589435
# length            -0.357612   0.874587  1.000000  0.841118  0.491029
# width             -0.232919   0.795144  0.841118  1.000000  0.279210
# height            -0.541038   0.589435  0.491029  0.279210  1.000000
# curbWeight        -0.227691   0.776386  0.877728  0.867032  0.295572
# engineSize        -0.105790   0.569329  0.683360  0.735433  0.067149
# bore              -0.134205   0.490378  0.607480  0.559204  0.176195
# stroke            -0.008965   0.161477  0.129739  0.182956 -0.056999
# compressionRatio  -0.178515   0.249786  0.158414  0.181129  0.261214
# horsepower         0.071622   0.352297  0.555003  0.642482 -0.110711
# peakRpm            0.274573  -0.361052 -0.287325 -0.219957 -0.322272
# cityMpg           -0.035823  -0.470414 -0.670909 -0.642704 -0.048640
# highwayMpg         0.034606  -0.544082 -0.704662 -0.677218 -0.107358
# price             -0.082391   0.584642  0.690628  0.751265  0.135486
#
#                   curbWeight  engineSize      bore    stroke  \
# symboling          -0.227691   -0.105790 -0.134205 -0.008965
# wheelBase           0.776386    0.569329  0.490378  0.161477
# length              0.877728    0.683360  0.607480  0.129739
# width               0.867032    0.735433  0.559204  0.182956
# height              0.295572    0.067149  0.176195 -0.056999
# curbWeight          1.000000    0.850594  0.649045  0.168929
# engineSize          0.850594    1.000000  0.594090  0.206675
# bore                0.649045    0.594090  1.000000 -0.055909
# stroke              0.168929    0.206675 -0.055909  1.000000
# compressionRatio    0.151362    0.028971  0.005203  0.186170
# horsepower          0.751034    0.810773  0.577273  0.090254
# peakRpm            -0.266306   -0.244618 -0.264269 -0.071493
# cityMpg            -0.757414   -0.653658 -0.594584 -0.042906
# highwayMpg         -0.797465   -0.677470 -0.594572 -0.044528
# price               0.834415    0.872335  0.543436  0.082310
#
#                   compressionRatio  horsepower   peakRpm   cityMpg  \
# symboling                -0.178515    0.071622  0.274573 -0.035823
# wheelBase                 0.249786    0.352297 -0.361052 -0.470414
# length                    0.158414    0.555003 -0.287325 -0.670909
# width                     0.181129    0.642482 -0.219957 -0.642704
# height                    0.261214   -0.110711 -0.322272 -0.048640
# curbWeight                0.151362    0.751034 -0.266306 -0.757414
# engineSize                0.028971    0.810773 -0.244618 -0.653658
# bore                      0.005203    0.577273 -0.264269 -0.594584
# stroke                    0.186170    0.090254 -0.071493 -0.042906
# compressionRatio          1.000000   -0.205874 -0.436221  0.324701
# horsepower               -0.205874    1.000000  0.130971 -0.803620
# peakRpm                  -0.436221    0.130971  1.000000 -0.113788
# cityMpg                   0.324701   -0.803620 -0.113788  1.000000
# highwayMpg                0.265201   -0.770908 -0.054257  0.971337
# price                     0.071107    0.810533 -0.101649 -0.686571
#
#                   highwayMpg     price
# symboling           0.034606 -0.082391
# wheelBase          -0.544082  0.584642
# length             -0.704662  0.690628
# width              -0.677218  0.751265
# height             -0.107358  0.135486
# curbWeight         -0.797465  0.834415
# engineSize         -0.677470  0.872335
# bore               -0.594572  0.543436
# stroke             -0.044528  0.082310
# compressionRatio    0.265201  0.071107
# horsepower         -0.770908  0.810533
# peakRpm            -0.054257 -0.101649
# cityMpg             0.971337 -0.686571
# highwayMpg          1.000000 -0.704692
# price              -0.704692  1.000000

# %%
sns.clustermap(df.corr())

# %% [markdown]
# ## Darstellung der Fahrzeugpreise nach Bauart(Body-Styyle)

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df, x='bodyStyle', y='price', jitter=0.3)

# %% [markdown]
# Hier kann man nun visuell erkennen(ohne entsprechende Python abfragen wie bswp "car_df.BodyStyle.value_counts()"), dass wohl in dem gegeben Datensatz die Fahrzeugtypen "Sedan" & hatchback am häfigsten auftretten. Das teruerst Fahrzeug scheint ein Harttop zu sein un der Fahrzeugtyp convertible steuert die wengisten Instanzen dem Dataframe bei.

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df, x='make', y='price', jitter=0.3)

# %% [markdown]
# Ich könnte natürlich nun an dieser Stelle erheblich detailierter werden und Abfragen nicht nur hinsichtlich des Body-Styles & make sondern nach allen anderen Kateforischen Variablen tätigen. Für den Ersteinedruck des DF genügt mir diest jedoch zunächst.

# %% [markdown]
# # Darstellung der Verteilung via Histogramm
# hier werden nun die nummerischen Werte in Form von Histogrammen dargestellt.

# %%
df.hist(bins=50, figsize=(20,8))
plt.show()

# %% [markdown]
# # Next Step
# Dieses NB dient meiner ersten Berührung mit dem Datensatz und der grundlegenden EDA. Soweit habe ich die Daten lediglich via tabellarischer bzw visueler Darstellung betrachtet, jedoch noch nicht modifiziert. Dies geschieht im nächsten Notebook mit dem Titel: 0_Preprocessing.
